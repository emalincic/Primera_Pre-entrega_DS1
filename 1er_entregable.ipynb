# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Especificaciones sobre las variables
#
# 1. Marca - nombre del fabricante del coche
# 2. Modelo - nombre del modelo del coche
# 3. Año- el año en que se fabricó el coche
# 4. Kilómetros - la cantidad de millas que ha recorrido el coche desde su producción
# 5. Motor - Capacidad
# 6. Transmisión - tipo de transmisión del coche
# 8. Tracción - tipo de transmisión del coche
# 9. Combustible - tipo de combustible que consume el coche
# 10. Color - color exterior del coche
# 11. DañosoAccidentes - si el coche estuvo involucrado en accidentes
# 12. PrimerPropietario - si el coche era propiedad de una sola persona
# 13. UsoPersonal - si el coche se utilizó solo para fines personales
# 14. Vendedor - nombre del vendedor
# 15. PuntajeVendedor - calificación del vendedor
# 16. PuntajeConductores - calificación del coche dada por los conductores
# 17. N_Reviews - la cantidad de reseñas del coche dejadas por los conductores
# 18. Precio - precio del coche
#
# Número original de filas: 762,091
# Número Actual de filas: 39401
# Fecha: Abril, 2023

# %%
df = pd.read_csv('Mercado_Autos_Usados_USA.csv')
df
# Out:
#          Marca                 Modelo   Año  Kilómetros Motor Transmisión  \
# 0      Porsche             911 GT2 RS  2018        4997  3.8L  Automatico
# 1      Porsche          911 Speedster  2019        2043  4.0L      Manual
# 2      Porsche          911 Speedster  2019        1308  4.0L      Manual
# 3      Porsche             911 GT2 RS  2018        5216  3.8L  Automatico
# 4      Porsche             911 GT2 RS  2018        7733  3.8L  Automatico
# ...        ...                    ...   ...         ...   ...         ...
# 39396      GMC              Envoy SLT  2002      194786  4.2L  Automatico
# 39397     Jeep  Grand Cherokee Laredo  2004      119784  4.0L  Automatico
# 39398    Dodge             Avenger SE  2008      162222  2.4L  Automatico
# 39399      Kia             Sorento LX  2007      251072  3.8L  Automatico
# 39400   Nissan              Maxima SE  2001      157000  3.0L  Automatico
#
#         Tracción Combustible   Color  DañosoAccidentes  PrimerPrpietario  \
# 0        Trasera       Nafta    Gris                 0                 0
# 1        Trasera       Nafta    Rojo                 0                 0
# 2        Trasera       Nafta   Negro                 0                 1
# 3        Trasera       Nafta   Negro                 1                 1
# 4        Trasera       Nafta    Gris                 0                 0
# ...          ...         ...     ...               ...               ...
# 39396        4x4       Nafta    Rojo                 1                 0
# 39397    Trasera       Nafta    Gris                 1                 0
# 39398  Delantera       Nafta   Negro                 1                 0
# 39399        4x4       Nafta  Blanco                 1                 0
# 39400  Delantera       Nafta   Arena                 0                 0
#
#        UsoPersonal                                      Vendedor  \
# 0                1                           Porsche Minneapolis
# 1                1                                 HGreg.com Lux
# 2                1                      Porsche Colorado Springs
# 3                1                                   Audi Fresno
# 4                1                                 Porsche Marin
# ...            ...                                           ...
# 39396            1                           Peterson Auto Group
# 39397            1                              Dan Deery Toyota
# 39398            0                         Western Avenue Nissan
# 39399            0                              Dan Deery Toyota
# 39400            1  Patriot Chrysler Dodge Jeep Ram of McAlester
#
#        PuntajeVendedor  PuntajeConductores  N_Reviews  Precio
# 0                  4.6                 4.8         33  396990
# 1                  4.7                 4.9         13  389000
# 2                  4.7                 4.9         13  383000
# 3                  4.7                 4.8         33  381999
# 4                  4.1                 4.8         33  379991
# ...                ...                 ...        ...     ...
# 39396              4.6                 4.4         42    1395
# 39397              4.6                 4.2        135    1200
# 39398              1.9                 4.2         83     975
# 39399              4.6                 4.5         29     900
# 39400              3.0                 4.2         22     500
#
# [39401 rows x 17 columns]

# %% [markdown]
# ## Bsqueda de nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39401 entries, 0 to 39400
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Marca               39401 non-null  object
#  1   Modelo              39401 non-null  object
#  2   Año                 39401 non-null  int64
#  3   Kilómetros          39401 non-null  int64
#  4   Motor               39401 non-null  object
#  5   Transmisión         39401 non-null  object
#  6   Tracción            39401 non-null  object
#  7   Combustible         39401 non-null  object
#  8   Color               39401 non-null  object
#  9   DañosoAccidentes    39401 non-null  int64
#  10  PrimerPrpietario    39401 non-null  int64
#  11  UsoPersonal         39401 non-null  int64
#  12  Vendedor            39401 non-null  object
#  13  PuntajeVendedor     39401 non-null  float64
#  14  PuntajeConductores  39401 non-null  float64
#  15  N_Reviews           39401 non-null  int64
#  16  Precio              39401 non-null  int64
# dtypes: float64(2), int64(7), object(8)
# memory usage: 5.1+ MB

# %%
df.isnull().sum()
# Out:
# Marca                 0
# Modelo                0
# Año                   0
# Kilómetros            0
# Motor                 0
# Transmisión           0
# Tracción              0
# Combustible           0
# Color                 0
# DañosoAccidentes      0
# PrimerPrpietario      0
# UsoPersonal           0
# Vendedor              0
# PuntajeVendedor       0
# PuntajeConductores    0
# N_Reviews             0
# Precio                0
# dtype: int64

# %% [markdown]
# ## Preguntas:

# %% [markdown]
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.

# %% [markdown]
# ## Resolución:

# %%
plt.figure()
sns.boxplot(data = df,
                x = 'Tracción',
                y = 'Precio',
                hue = 'Tracción',
                showfliers = False)
# Out:
# <Axes: xlabel='Tracción', ylabel='Precio'>

# %%
plt.figure()
sns.histplot(data=df,
             y='Marca',
             bins = 30,           
             alpha = 0.3,
             kde = True,
             stat='probability')
# Out:
# <Axes: xlabel='Probability', ylabel='Marca'>

# %%
plt.figure()
sns.scatterplot(data=df,
            x='Precio',
            y='Color')
# Out:
# <Axes: xlabel='Precio', ylabel='Color'>

# %%
#Precio en millones
#Se observa el incremento del precio cuanto mayor sea el puntaje que le dan los conductores
plt.figure()
sns.scatterplot(data=df,
                y='Precio',
                x='PuntajeConductores')
# Out:
# <Axes: xlabel='PuntajeConductores', ylabel='Precio'>

# %%
#Precio en millones
#Se observa un leve incremento del precio cuanto mayor sea el puntaje que le dan los vendedores
plt.figure()
sns.scatterplot(data=df,
                y='Precio',
                x='PuntajeVendedor')
# Out:
# <Axes: xlabel='PuntajeVendedor', ylabel='Precio'>

# %%
plt.figure()
sns.scatterplot(data=df,
                x='Año',
                y='Precio')
# Out:
# <Axes: xlabel='Año', ylabel='Precio'>

# %%
plt.figure()
sns.barplot(data=df,
            y='Marca',
            x='Precio')
plt.title('Marcas más caras')
plt.figure()
sns.histplot(data=df,
            y='Marca')
plt.title('Cantidad de autos publicados por marca')
# Out:
# Text(0.5, 1.0, 'Cantidad de autos publicados por marca')

# %%
Reducción = df['Kilómetros'].quantile(0.9)
plt.figure(figsize=(15,5))
plt.xticks(rotation=45)
sns.lineplot(data=df[(df['Kilómetros']<Reducción)],
             y='Precio',
             x='Kilómetros')
# Out:
# <Axes: xlabel='Kilómetros', ylabel='Precio'>
